# %% [markdown]
# Student first name: Jenny
#
#
# ---
#
#
# Student last name: TING
#
#
# ---
#
#
# Student number: 261301330

# %% [markdown]
# # Assignment 1 - total points 15

# %% [markdown]
# 1. (total 2 points) Chapter 1 [Hands-On Data Preprocessing in Python](https://www.packtpub.com/product/hands-on-data-preprocessing-in-python/9781801072137)
#
# ##### Excercise 3
# For this exercise you need to use a new dataset: billboard.csv. Visit https://www.billboard.com/charts/hot-100 and see the latest song rankings of the day. This dataset presents information and ranking of 317 song tracks in 80 columns. The first four columns are artist, track, time, and date_e. The first columns are intuitive descriptions of song tracks. The column date_e shows the date that the songs entered the hot-100 list. The rest of 76 columns are songs ranking at the end of each weeks from 'w1' to 'w76'. Download and read this dataset using pandas and answer the following questions.

# %%
import pandas as pd
import matplotlib.pyplot as plt

bb_df = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/Hands-On-Data-Preprocessing-in-Python/main/Chapter01/billboard.csv')
bb_df.head()
# Out:
#                 artist                                  track  time  \
# 0      Destiny's Child               Independent Women Part I  3:38
# 1              Santana                           Maria, Maria  4:18
# 2        Savage Garden                     I Knew I Loved You  4:07
# 3              Madonna                                  Music  3:45
# 4  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#        date_e  w1    w2    w3    w4    w5    w6  ...  w67  w68  w69  w70  w71  \
# 0  2000-09-23  78  63.0  49.0  33.0  23.0  15.0  ...  NaN  NaN  NaN  NaN  NaN
# 1  2000-02-12  15   8.0   6.0   5.0   2.0   3.0  ...  NaN  NaN  NaN  NaN  NaN
# 2  1999-10-23  71  48.0  43.0  31.0  20.0  13.0  ...  NaN  NaN  NaN  NaN  NaN
# 3  2000-08-12  41  23.0  18.0  14.0   2.0   1.0  ...  NaN  NaN  NaN  NaN  NaN
# 4  2000-08-05  57  47.0  45.0  29.0  23.0  18.0  ...  NaN  NaN  NaN  NaN  NaN
#
#    w72  w73  w74  w75  w76
# 0  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 80 columns]

# %% [markdown]
#     a)	(1point) Write one line of code that gives you a great idea of how many null values each column has. If there are any columns that have no non-null values drop them.

# %%
# Your code
print(bb_df.dropna().isnull().sum())
# Out:
# artist    0
# track     0
# time      0
# date_e    0
# w1        0
#          ..
# w72       0
# w73       0
# w74       0
# w75       0
# w76       0
# Length: 80, dtype: int64

# %% [markdown]
#     b)	(1 point) With a for loop, draw and study the values in each of the remaining W columns. (hint for each w column draw histogram and box plot)

# %%
import matplotlib.pyplot as plt

 # axis check the it vertically which is Week and drop the columns contains ALL NAN
df = bb_df.dropna(axis=1, how='all')

 #w_cols is a Series like W1,W2,W3 which contains all rows in the column
w_cols = [c for c in df.columns if c.startswith('w')] 

# using for loop for draw the graphics 
for col in w_cols:
    data = df[col].dropna() # iterate each items within the Series, drop the nan.
    
    # histogram
    plt.figure()
    plt.hist(data, bins=10)
    plt.title(f'Histogram of {col}')
    plt.xlabel('Rank')
    plt.ylabel('Frequency')
    plt.show()
    
    # boxplot
    plt.figure()
    plt.boxplot(data)
    plt.title(f'Box Plot of {col}')
    plt.ylabel('Rank')
    plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 2. (total 4 points)Chapter 3 [Hands-On Data Preprocessing in Python](https://www.packtpub.com/product/hands-on-data-preprocessing-in-python/9781801072137)
#
# ##### Excercise 4
#
# For this exercise, we are going to use fatal-police-shootings-data.csv. There are a lot of debates, discussions, dialogues, and protests happening in the US surrounding police killings. The Washington Post has been collecting data on all fatal police shootings in the US. The dataset available to the government and the public alike has date, age, gender, race, location, and other situational information of these fatal police shootings. You can read more about this data on https://www.washingtonpost.com/graphics/investigations/police-shootings-database/, and you can download the last version of the data from https://github.com/washingtonpost/data-police-shootings

# %%
import pandas as pd

incident_df = pd.read_csv('https://raw.githubusercontent.com/PacktPublishing/Hands-On-Data-Preprocessing-in-Python/main/Chapter03/fatal-police-shootings-data.csv')
incident_df
# Out:
#         id                 name        date   manner_of_death         armed  \
# 0        3           Tim Elliot  2015-01-02              shot           gun
# 1        4     Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5   John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8      Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9    Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                  ...         ...               ...           ...
# 6063  6624          William Ice  2021-02-20              shot           gun
# 6064  6626    Hailey Stainbrook  2021-02-20              shot           gun
# 6065  6625                  NaN  2021-02-21              shot           gun
# 6066  6628                  NaN  2021-02-21              shot  undetermined
# 6067  6629  Clayton James Adams  2021-02-22              shot           gun
#
#        age gender race             city state  signs_of_mental_illness  \
# 0     53.0      M    A          Shelton    WA                     True
# 1     47.0      M    W            Aloha    OR                    False
# 2     23.0      M    H          Wichita    KS                    False
# 3     32.0      M    W    San Francisco    CA                     True
# 4     39.0      M    H            Evans    CO                    False
# ...    ...    ...  ...              ...   ...                      ...
# 6063  38.0      M    W           Lonoke    AR                    False
# 6064  30.0      F    W          Lincoln    NE                    False
# 6065   NaN      M  NaN           Braham    MN                    False
# 6066   NaN      M  NaN            Anoka    MN                    False
# 6067  30.0      M    W  McDowell County    NC                    False
#
#      threat_level         flee  body_camera  longitude  latitude  \
# 0          attack  Not fleeing        False   -123.122    47.247
# 1          attack  Not fleeing        False   -122.892    45.487
# 2           other  Not fleeing        False    -97.281    37.695
# 3          attack  Not fleeing        False   -122.422    37.763
# 4          attack  Not fleeing        False   -104.692    40.384
# ...           ...          ...          ...        ...       ...
# 6063       attack          Car        False        NaN       NaN
# 6064       attack          Car        False    -96.643    40.893
# 6065       attack        Other        False        NaN       NaN
# 6066        other        Other        False    -93.387    45.198
# 6067       attack          NaN        False    -82.084    35.698
#
#       is_geocoding_exact
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 6063                True
# 6064                True
# 6065                True
# 6066                True
# 6067                True
#
# [6068 rows x 17 columns]

# %% [markdown]
#     a)	(1 point) What is the best definition of the data object for this dataset?

# %% [markdown]
# # Your answer
# The data object for this dataset refers to a fatal police shooting incident in the United States.
# Each row means one incident with different attributes such as time, location, victim demographics, and situational context.

# %% [markdown]
#     b)	(1 point)Are there any attributes in the data that only have one value? Use .unique() function to check. If there are remove them from the data and update the definition of the data object.

# %%
# Your answer - way 1
unique_counts = incident_df.nunique()
print(unique_counts)

one_value = unique_counts[unique_counts ==1].index.tolist()
print("The list of attributes that only has one value:", one_value)
# Out:
# id                         6068
# name                       5832
# date                       2083
# manner_of_death               2
# armed                        98
# age                          78
# gender                        2
# race                          6
# city                       2673
# state                        51
# signs_of_mental_illness       2
# threat_level                  3
# flee                          4
# body_camera                   2
# longitude                  5118
# latitude                   4634
# is_geocoding_exact            2
# dtype: int64
# The list of attributes that only has one value: []

# %%
# Your answer - way 2
for col in incident_df.columns: #check if there are any sttributes in the data that have only 1 value
    if incident_df[col].nunique() == 1:
        print(f"Column '{col}' has only one unique value: {incident_df[col].unique()}") #if there is, print it out

# %%
incident_df = incident_df.loc[:, incident_df.nunique() > 1] #remove from data and print it out
print(incident_df)
# Out:
#         id                 name        date   manner_of_death         armed  \
# 0        3           Tim Elliot  2015-01-02              shot           gun
# 1        4     Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5   John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8      Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9    Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                  ...         ...               ...           ...
# 6063  6624          William Ice  2021-02-20              shot           gun
# 6064  6626    Hailey Stainbrook  2021-02-20              shot           gun
# 6065  6625                  NaN  2021-02-21              shot           gun
# 6066  6628                  NaN  2021-02-21              shot  undetermined
# 6067  6629  Clayton James Adams  2021-02-22              shot           gun
#
#        age gender race             city state  signs_of_mental_illness  \
# 0     53.0      M    A          Shelton    WA                     True
# 1     47.0      M    W            Aloha    OR                    False
# 2     23.0      M    H          Wichita    KS                    False
# 3     32.0      M    W    San Francisco    CA                     True
# 4     39.0      M    H            Evans    CO                    False
# ...    ...    ...  ...              ...   ...                      ...
# 6063  38.0      M    W           Lonoke    AR                    False
# 6064  30.0      F    W          Lincoln    NE                    False
# 6065   NaN      M  NaN           Braham    MN                    False
# 6066   NaN      M  NaN            Anoka    MN                    False
# 6067  30.0      M    W  McDowell County    NC                    False
#
#      threat_level         flee  body_camera  longitude  latitude  \
# 0          attack  Not fleeing        False   -123.122    47.247
# 1          attack  Not fleeing        False   -122.892    45.487
# 2           other  Not fleeing        False    -97.281    37.695
# 3          attack  Not fleeing        False   -122.422    37.763
# 4          attack  Not fleeing        False   -104.692    40.384
# ...           ...          ...          ...        ...       ...
# 6063       attack          Car        False        NaN       NaN
# 6064       attack          Car        False    -96.643    40.893
# 6065       attack        Other        False        NaN       NaN
# 6066        other        Other        False    -93.387    45.198
# 6067       attack          NaN        False    -82.084    35.698
#
#       is_geocoding_exact
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 6063                True
# 6064                True
# 6065                True
# 6066                True
# 6067                True
#
# [6068 rows x 17 columns]

# %% [markdown]
#     c)	(1 point) What type of values do the remaining attributes carry?

# %%
# Your answer
incident_df.dtypes 
#There are numerical (age, latitude, longitude) data type
#Categorical: gender, race, city, state, armed, manner_of_death, threat_level, flee
#Boolean: signs_of_mental_illness, body_camera, is_geocoding_exact
#Date
# Out:
# id                           int64
# name                        object
# date                        object
# manner_of_death             object
# armed                       object
# age                        float64
# gender                      object
# race                        object
# city                        object
# state                       object
# signs_of_mental_illness       bool
# threat_level                object
# flee                        object
# body_camera                   bool
# longitude                  float64
# latitude                   float64
# is_geocoding_exact            bool
# dtype: object

# %% [markdown]
#     d)	(1 point)Compare the statistical information of the numerical attributes and see if any of them are a candidate for data redundancy. (hint you need to find corolation on numerical attribiutes)

# %%
# Your answer
incident_df.describe() #examine stat properties
# Out:
#                 id          age    longitude     latitude
# count  6068.000000  5802.000000  5771.000000  5771.000000
# mean   3363.828444    37.160290   -97.238779    36.660617
# std    1898.394615    13.039693    16.629397     5.377469
# min       3.000000     6.000000  -158.137000    19.498000
# 25%    1716.750000    27.000000  -112.117000    33.475500
# 50%    3369.500000    35.000000   -94.386000    36.096000
# 75%    5019.250000    46.000000   -83.067000    39.986500
# max    6629.000000    91.000000   -68.014000    71.301000

# %%
incident_df.corr(numeric_only=True) #compute the correlation matrix
# According to the correlation matrix, most numerical attributes have very low correlations with each other. 
# Ex. very weak correlation between latitude and longitude (-0.116595). Thus, none of the numerical attributes are redundant. 
# All of them can be kept for further analysis.
# Out:
#                                id       age  signs_of_mental_illness  \
# id                       1.000000  0.034946                -0.058255
# age                      0.034946  1.000000                 0.111744
# signs_of_mental_illness -0.058255  0.111744                 1.000000
# body_camera              0.060787 -0.049961                 0.055715
# longitude                0.004482  0.057657                 0.015192
# latitude                -0.002577 -0.014671                 0.036581
# is_geocoding_exact       0.015706 -0.002037                -0.001561
#
#                          body_camera  longitude  latitude  is_geocoding_exact
# id                          0.060787   0.004482 -0.002577            0.015706
# age                        -0.049961   0.057657 -0.014671           -0.002037
# signs_of_mental_illness     0.055715   0.015192  0.036581           -0.001561
# body_camera                 1.000000  -0.052102  0.027612            0.013810
# longitude                  -0.052102   1.000000 -0.116595           -0.009090
# latitude                    0.027612  -0.116595  1.000000           -0.008933
# is_geocoding_exact          0.013810  -0.009090 -0.008933            1.000000

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# **3**. (total 1 points)Chapter 4 [Hands-On Data Preprocessing in Python](https://www.packtpub.com/product/hands-on-data-preprocessing-in-python/9781801072137)
#
# ##### Excercise 1
# (1 point)In your own words, describe the difference between a dataset and a database.

# %% [markdown]
# # Your answer
# A dataset is a collection of related data. It is usually organized in a single table or file, where each row is a record and each column is a variable or attribute. It's typically used for analysis, such as in a spreadsheet or a CSV file.
#
# On the other side, a database is a structured system that stores multiple datasets and allows for more complex data storage, retrieval, and management. It can handle large volumes of data across multiple related tables using a database management system such as MySQL, PostgreSQL, or SQLite.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 4. (total 2 points)Chapter 7 [Business Analytics, 2nd Edition](https://www.mheducation.com/highered/product/business-analytics-lertwachara-chen/M9781264302802.html)
#
# ##### Excercise 7.1
#
# 1. Using data from 50 workers, a researcher estimate
#
# $$ \text{Wage} = b_0 + b_1 \text{Education} + b_2 \text{Experience} + b_3 \text{Age}  $$
# where Wage is the hourly wage rate and Education, Experience, and Age are the years of higher education, the years of experience, and the age of the worker, respecttively. A portion of regression result is shown in the follwing table.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#     a)    (1point) what are the estimate for b1, b2

# %%
# Your answer
#The estimate for b1 and b2 are as follows: 
#b1(Education): 1.44 
#b2(Experience): 0.45

# %% [markdown]
#     b)    (1point) Predict the hourly wage rate for 30-year-old worker with four year of higher education and three years of experience.

# %%
# Your answer
b0 = 7.87 #intercept
b1 = 1.44 #education
b2 = 0.45 #experience
b3 = -0.01 #age

est_wage = round(b0 + b1*4 + b2*3 + b3*30, 2)
print("The predicted hourly wage rate for 30-year-old worker with four year of higher education and three years of experience is $", est_wage, "per hour." )
# Out:
# The predicted hourly wage rate for 30-year-old worker with four year of higher education and three years of experience is $ 14.68 per hour.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 5. (total 3 points)Chapter 7 [Business Analytics, 2nd Edition](https://www.mheducation.com/highered/product/business-analytics-lertwachara-chen/M9781264302802.html)
#
# ##### Excercise 7.1
#
# 6. The director of graduate admission at a large university is analyzing the relationship between scores on the math portion of Graduate Record Examination (GRE) and subsequent performace in graduate school, as measured by student`s avrage (GPA). the accompaanying data file shows GPA and GRE of 24 students.

# %%
import numpy as np
import pandas as pd
gpaDf =  pd.read_excel("https://www.dropbox.com/scl/fi/24jfn2u4rsn6e45bvzkrs/GPA.xlsx?rlkey=9ecqtc90bmntcsucdy8gzyt24&dl=1")
gpaDf
# Out:
#     GPA  GRE
# 0   3.0  700
# 1   3.5  720
# 2   3.2  650
# 3   3.7  750
# 4   3.1  680
# 5   3.9  730
# 6   3.3  740
# 7   3.5  780
# 8   3.0  690
# 9   3.5  730
# 10  3.2  640
# 11  3.7  740
# 12  3.1  690
# 13  3.9  720
# 14  3.3  740
# 15  3.5  750
# 16  2.9  690
# 17  3.3  730
# 18  3.3  640
# 19  3.6  740
# 20  3.0  690
# 21  3.8  720
# 22  3.2  740
# 23  3.5  760

# %% [markdown]
#     a) (2points) Find regression model equation for the model: GPA = b0 + B1 GRE

# %%
import pandas as pd
import statsmodels.api as sm

# independent , dependent
X = sm.add_constant(gpaDf[["GRE"]])
y = gpaDf["GPA"]

# OLS  Train linear regression model
model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GPA   R-squared:                       0.274
# Model:                            OLS   Adj. R-squared:                  0.241
# Method:                 Least Squares   F-statistic:                     8.316
# Date:                Tue, 24 Jun 2025   Prob (F-statistic):            0.00862
# Time:                        20:09:28   Log-Likelihood:               -0.29776
# No. Observations:                  24   AIC:                             4.596
# Df Residuals:                      22   BIC:                             6.952
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4256      1.024      0.416      0.682      -1.698       2.549
# GRE            0.0041      0.001      2.884      0.009       0.001       0.007
# ==============================================================================
# Omnibus:                        1.633   Durbin-Watson:                   2.599
# Prob(Omnibus):                  0.442   Jarque-Bera (JB):                1.406
# Skew:                           0.458   Prob(JB):                        0.495
# Kurtosis:                       2.248   Cond. No.                     1.40e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
b0, b1 = model.params["const"], model.params["GRE"]

# %% [markdown]
#     b) (1 point) what is a student`s prediction GPA if he/she scored 710 on math portion of GRE

# %%
# Your answer
b0 = 0.4256 #intercept
coefficient = 0.0041 #GRE Coefficient
predicted_gpa = round(b0 + coefficient*710, 2)
print("A students' predicted GPA if he/she scored 710 on math portion of GRE is", predicted_gpa, ".")
# Out:
# A students' predicted GPA if he/she scored 710 on math portion of GRE is 3.34 .

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 6. (totla 3 points)Chapter 7 [Business Analytics, 2nd Edition](https://www.mheducation.com/highered/product/business-analytics-lertwachara-chen/M9781264302802.html)
#
# ##### Excercise 7.1
#
# 10. The maintenance manager at a trucking company wants to build a regression model to forcast the time unyil the first engine overhaul(Time in years) based on four predictor variables for 25 trucks:
#     1. anual miles driven (Miles in 1000s)
#     2. avrage load weight (Load in tons)
#     3. average driving speed (Speed in mph)
#     4. oil change interval (Oil in 1000s of miles).

# %%
import numpy as np
import pandas as pd
engineDf =  pd.read_excel("https://www.dropbox.com/scl/fi/dcoz9yw3f8yywtzy82f4z/Engine.xlsx?rlkey=n53hfjjsrddywktksj156jra5&dl=1")
engineDf.head()
# Out:
#    Time  Miles  Load  Speed  Oil
# 0   7.9   42.8    19     46   15
# 1   0.9   98.5    25     46   29
# 2   8.5   43.4    21     64   14
# 3   1.3  110.7    27     60   26
# 4   1.4  102.3    28     51   17

# %% [markdown]
#     a) (2 point)find model regression equation (use all four predictor variables)

# %%
# your answer
# https://www.statsmodels.org/stable/index.html
import statsmodels.api as sm

# Define predictors and response
X = engineDf[['Miles', 'Load', 'Speed', 'Oil']]  # All four predictors
X = sm.add_constant(X)  # Add intercept term
y = engineDf['Time']  # Target variable

# Fit the regression model
model = sm.OLS(y, X).fit()

# Print summary of the model
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.910
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     50.47
# Date:                Tue, 24 Jun 2025   Prob (F-statistic):           3.58e-10
# Time:                        20:06:20   Log-Likelihood:                -27.456
# No. Observations:                  25   AIC:                             64.91
# Df Residuals:                      20   BIC:                             71.01
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.4343      2.192      6.128      0.000       8.861      18.008
# Miles         -0.0896      0.012     -7.385      0.000      -0.115      -0.064
# Load          -0.0732      0.091     -0.806      0.429      -0.262       0.116
# Speed          0.0048      0.029      0.164      0.871      -0.056       0.065
# Oil           -0.0297      0.039     -0.755      0.459      -0.112       0.052
# ==============================================================================
# Omnibus:                        1.355   Durbin-Watson:                   1.538
# Prob(Omnibus):                  0.508   Jarque-Bera (JB):                0.938
# Skew:                           0.116   Prob(JB):                        0.626
# Kurtosis:                       2.080   Cond. No.                     1.30e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
#     b) (1point) Predict the time before the first engine overhaul for particular truck driven 60000 miles per year with an average load of 22 tons, an average driving speed of 57 mph, and 18000 miles between oil changes.

# %%
# Your answer
intercept = 13.4343
miles_coeff = -0.0896
load_coeff = -0.0732
speed_coeff = 0.0048
oil_coeff = -0.0297

miles_in_thousands = 60
load = 22
speed = 57
oil_in_thousands = 18

time = round(intercept+(miles_coeff*miles_in_thousands)+(load_coeff*load)+(speed_coeff*speed)+(oil_coeff*oil_in_thousands),2)
print("The predicted time before the first engine overhaul is approximately", time, "years.")
# Out:
# The predicted time before the first engine overhaul is approximately 6.19 years.

# %% [markdown]
# ### ✅ Extra 5 Points
#
# To earn these additional points, make sure you:
#
# - Register your model in the registry group using the format:
#   `<lastName>_<studentNumber>_<modelName>`
# - Ensure the registered model includes:
#   - A proper **transformer**
#   - A working **main predictor**
# - Confirm that the model can be called through the FastAPI `/dashboard` endpoint using the `predict` function.
#
# > **Note:** These are bonus points that can contribute to improving your final course grade.

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from functools import partial
from dotenv import load_dotenv

from pathlib import Path

env_path = Path(".env-live")

if env_path.exists():
    load_dotenv(dotenv_path=env_path)
import os
os.environ['JRJ_MODEL_REGISTRY_S3_BUCKET_NAME']
# Out:
# '273-g2'

# %%
from jrjModelRegistry.jrjModelRegistry import registerAJrjModel
import statsmodels.api as sm

# %%
predictGPA = model.predict(sm.add_constant(gpaDf["GRE"]))
predictGPA
# Out:
# 0     3.313125
# 1     3.395625
# 2     3.106875
# 3     3.519375
# 4     3.230625
# 5     3.436875
# 6     3.478125
# 7     3.643125
# 8     3.271875
# 9     3.436875
# 10    3.065625
# 11    3.478125
# 12    3.271875
# 13    3.395625
# 14    3.478125
# 15    3.519375
# 16    3.271875
# 17    3.436875
# 18    3.065625
# 19    3.478125
# 20    3.271875
# 21    3.395625
# 22    3.478125
# 23    3.560625
# dtype: float64

# %%
def GPA_Model_Transformer(dataForTransfer=None):
    import pandas as pd
    import statsmodels.api as sm
    dfTransformer = pd.DataFrame(dataForTransfer)
    dfTransformer = sm.add_constant(dfTransformer[["GRE"]])
    return dfTransformer

# %%
from functools import partial
def GPA_Model_MainPredictor(self, transformedData):
    return self.predict(transformedData)

model.mainPredictor = partial(GPA_Model_MainPredictor, model)
model.transformer = GPA_Model_Transformer

# %%
# Example input
GPA_Model_SampleData = {"GRE": [760, 320]}
test_df = GPA_Model_Transformer(GPA_Model_SampleData)
print(test_df)
print()

#Output
print("Example Output:")
print(model.predict(test_df))
print()
print(model.mainPredictor(test_df))
# Out:
#    const  GRE
# 0    1.0  760
# 1    1.0  320
#
# Example Output:
# 0    3.560625
# 1    1.745625
# dtype: float64
#
# 0    3.560625
# 1    1.745625
# dtype: float64

# %%
#set up model's metadata
GPA_Model_Metadata = {
    "modelName": "Jenny_TING_GPA_PREDICTION",
    "version": "1.0.2",
    "params": model.params.to_dict(),
    "score": float(model.rsquared),
    "modelLibrary": "sm.OLS",
    "libraryMetadata": {
        "pvalues": model.pvalues.to_dict(),
        "r_squared": float(model.rsquared),
        "adj_r_squared": float(model.rsquared_adj),
    },
    "sampleData": {
        "dataForTransfer": GPA_Model_SampleData
    },
    "modelType": "model",
    "keepLastOnly": False
}

# %%
from jrjModelRegistry.jrjModelRegistry import registerAJrjModel

registerAJrjModel(model, GPA_Model_Metadata)
# Out:
# ✅ Uploaded encrypted ZIP to s3://273-g2/Jenny_TING_GPA_PREDICTION__1.0.2.pkl.zip
# {'_id': '685b3e5cd2b035291a5302cf',
#  'modelName': 'Jenny_TING_GPA_PREDICTION',
#  'version': '1.0.2',
#  'params': {'const': 0.4256250000000037, 'GRE': 0.004124999999999997},
#  'score': 0.27430730478589405,
#  'modelLibrary': 'sm.OLS',
#  'libraryMetadata': {'pvalues': {'const': 0.6817218241632765,
#    'GRE': 0.008621264218965969},
#   'r_squared': 0.27430730478589405,
#   'adj_r_squared': 0.24132127318525287},
#  'sampleData': {'dataForTransfer': {'GRE': [760, 320]}},
#  'modelType': 'model',
#  'keepLastOnly': False,
#  'modelSizeBytes': 6946,
#  'zippedModelSizeBytes': 3212,
#  's3Url': '273-g2/Jenny_TING_GPA_PREDICTION__1.0.2.pkl.zip',
#  'createdAt': '2025-06-25T00:10:04.497Z',
#  'updatedAt': '2025-06-25T00:10:04.497Z'}
